# %%
import pandas as pd
df = pd.read_csv(r'C:\All_Project\finaltrain\notebooks\data\finalTrain.csv')
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.2            30.327968             78.046106
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         43730.000000             43676.000000         45584.000000
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# ...

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# df has null values

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.heatmap(df.isnull(),cbar = False,cmap='viridis')
plt.show()

# %% [markdown]
# you can see there are many columns in df who have missing values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# df has no duplicates

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'],format = '%d-%m-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  datetime64[ns]
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %% [markdown]
# Finding the distance using geodesic in kms

# %%
cols=['Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude']
for col in cols:
    df[col]= abs(df[col])

# %%
import numpy as np
from geopy.distance import geodesic

df['distance']=np.zeros(len(df))
restaurant_cordinates_df=df[['Restaurant_latitude','Restaurant_longitude']].to_numpy()
delivery_location_cordinates_df=df[['Delivery_location_latitude','Delivery_location_longitude']].to_numpy()

for i in range(len(df)):
    df['distance'].loc[i]=geodesic(restaurant_cordinates_df[i],delivery_location_cordinates_df[i])
# Out:
# <ipython-input-36-83d651b33f76>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['distance'].loc[i]=geodesic(restaurant_cordinates_df[i],delivery_location_cordinates_df[i])

# %%
df['distance'] = df['distance'].astype('str').str.extract('(\d+)')

# %%
df['distance'] = df['distance'].astype("float64")
df['distance']
# Out:
# 0        10.0
# 1         6.0
# 2        13.0
# 3         2.0
# 4        19.0
#          ...
# 45579     1.0
# 45580    10.0
# 45581     4.0
# 45582     6.0
# 45583    12.0
# Name: distance, Length: 45584, dtype: float64

# %%
df['distance'].describe()
# Out:
# count    45584.000000
# mean         9.245722
# std          5.565636
# min          1.000000
# 25%          4.000000
# 50%          9.000000
# 75%         13.000000
# max         20.000000
# Name: distance, dtype: float64

# %% [markdown]
# Finding the Order preparation time in minutes

# %%
df['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', nan, '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
# ...

# %%
df['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25',
#        '0.458333333', '19:15', '16:55', '11:40', '15:15', '22:55',
#        '22:25', '20:55', '23:05', '0.75', '0.958333333', '09:40', '20:20',
#        '22:35', '0.916666667', '23:55', '15:40', '10:30', '0.875',
#        '10:50', '16:05', '20:15', '12:15', '15:45', '22:15', '10:45',
#        '15:30', '24:05:00', '21:25', '12:45', '21:15', '18:20', '18:25',
#        '11:50', '12:50', '10:55', '21:40', '10:20', '17:55', '23:50',
#        '12:55', '24:10:00', '10:40', '0.375', '20:45', '0.833333333',
#        '23:15', '22:20', '21:05', '0.708333333', '24:15:00', '21:20',
# ...

# %%
def filter_int_float_values(column_df):
    for i in range(len(column_df)):
        if '.' in str(column_df.iloc[i]) or  column_df.iloc[i] == '1':
            column_df.iloc[i] = np.nan

    return column_df
df['Time_Orderd'] = filter_int_float_values(df['Time_Orderd']).str.slice(0,5)
df['Time_Order_picked'] = filter_int_float_values(df['Time_Order_picked']).str.slice(0,5)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-42-f5a2a61f76b0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_df.iloc[i] = np.nan
# <ipython-input-42-f5a2a61f76b0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_df.iloc[i] = np.nan
# <ipython-input-42-f5a2a61f76b0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_df.iloc[i] = np.nan
# ...

# %%
df['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', nan, '09:45', '08:40', '17:25',
#        '19:45', '19:10', '10:55', '21:40', '16:45', '11:30', '15:10',
#        '22:45', '22:10', '20:45', '22:50', '17:55', '09:25', '20:15',
#        '22:25', '22:40', '23:50', '15:25', '10:20', '20:55', '10:40',
#        '15:55', '20:10', '12:10', '15:30', '10:35', '21:10', '20:50',
#        '12:35', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '14:20', '10:15', '08:50', '17:45',
#        '16:35', '08:30', '21:45', '19:40', '14:50', '18:10', '12:20',
# ...

# %%
df['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25', nan, '19:15',
#        '16:55', '11:40', '15:15', '22:55', '22:25', '20:55', '23:05',
#        '09:40', '20:20', '22:35', '23:55', '15:40', '10:30', '10:50',
#        '16:05', '20:15', '12:15', '15:45', '22:15', '10:45', '15:30',
#        '24:05', '21:25', '12:45', '21:15', '18:20', '18:25', '11:50',
#        '12:50', '10:55', '21:40', '10:20', '17:55', '23:50', '12:55',
#        '24:10', '10:40', '20:45', '23:15', '22:20', '21:05', '24:15',
#        '21:20', '14:35', '10:25', '09:05', '16:50', '08:40', '23:40',
#        '21:50', '19:55', '10:35', '09:25', '17:20', '19:30', '17:25',
# ...

# %% [markdown]
# there has been nan values in those column

# %%
df['Time_Orderd'].fillna(df['Time_Orderd'].mode()[0],inplace = True)
df['Time_Order_picked'].fillna(df['Time_Order_picked'].mode()[0], inplace = True)

# %% [markdown]
# Concatenating :00 atlast to make it date format and also we can calculate the preparation time using these values

# %%
df['Time_Orderd'] = df['Time_Orderd'] + ':00'
df['Time_Order_picked'] = df['Time_Order_picked'] + ':00'
df = df.reset_index()
df.drop(columns=['index'],axis=1,inplace=True)

# %%
df['Time_Order_picked']
# Out:
# 0        22:10:00
# 1        15:05:00
# 2        17:40:00
# 3        09:30:00
# 4        20:05:00
#            ...
# 45579    11:45:00
# 45580    20:10:00
# 45581    24:05:00
# 45582    13:40:00
# 45583    17:15:00
# Name: Time_Order_picked, Length: 45584, dtype: object

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
# ...

# %%
df['Time_Orderd']=pd.to_timedelta(df['Time_Orderd'])
df['Time_Order_picked']=pd.to_timedelta(df['Time_Order_picked'])

df['Time_Order_picked_formatted']=np.where(df['Time_Order_picked'] < df['Time_Orderd'], df['Order_Date'] + pd.DateOffset(1)+df['Time_Order_picked'], df['Order_Date']+df['Time_Order_picked'])
df['Time_Ordered_formatted'] = df['Order_Date']+ df['Time_Orderd']
df['order_preparation_time']=((df['Time_Order_picked_formatted']- df['Time_Ordered_formatted']).dt.total_seconds())/60

# %%
df['order_preparation_time'].value_counts()
# Out:
# order_preparation_time
# 15.0      12074
# 10.0      12028
# 5.0       12022
# 1415.0      321
# 75.0        178
#           ...
# 955.0         1
# 1110.0        1
# 1065.0        1
# 900.0         1
# 805.0         1
# Name: count, Length: 199, dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# distance                          0
# Time_Order_picked_formatted       0
# Time_Ordered_formatted            0
# order_preparation_time            0
# dtype: int64

# %%
df['Delivery_person_Age'].fillna(np.mean(df['Delivery_person_Age']),inplace =True)

# %%
df['Delivery_person_Ratings'].fillna(np.mean(df['Delivery_person_Ratings']),inplace =True)

# %%
df['Weather_conditions'].fillna(df['Weather_conditions'].mode()[0],inplace=True)
df['Road_traffic_density'].fillna(df['Road_traffic_density'].mode()[0],inplace=True)
df['multiple_deliveries'].fillna(np.mean(df['multiple_deliveries']),inplace=True)
df['Festival'] = df['Festival'].fillna('No')
df['City'].fillna(df['City'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# distance                       0
# Time_Order_picked_formatted    0
# Time_Ordered_formatted         0
# order_preparation_time         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          45584 non-null  float64
#  3   Delivery_person_Ratings      45584 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  datetime64[ns]
#  9   Time_Orderd                  45584 non-null  timedelta64[ns]
#  10  Time_Order_picked            45584 non-null  timedelta64[ns]
#  11  Weather_conditions           45584 non-null  object
# ...

# %%
columns = ['Delivery_person_Age','Delivery_person_Ratings','distance','order_preparation_time','Weather_conditions','Road_traffic_density','Vehicle_condition','Type_of_vehicle','multiple_deliveries','Festival','City','Time_taken (min)']
df = df[columns]

# %%
df
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  distance  \
# 0                     36.0                      4.2      10.0
# 1                     21.0                      4.7       6.0
# 2                     23.0                      4.7      13.0
# 3                     34.0                      4.3       2.0
# 4                     24.0                      4.7      19.0
# ...                    ...                      ...       ...
# 45579                 30.0                      4.8       1.0
# 45580                 21.0                      4.6      10.0
# 45581                 30.0                      4.9       4.0
# 45582                 20.0                      4.7       6.0
# 45583                 23.0                      4.9      12.0
#
#        order_preparation_time Weather_conditions Road_traffic_density  \
# 0                        15.0                Fog                  Jam
# 1                        10.0             Stormy                 High
# ...

# %% [markdown]
# # Data visualization

# %%
numerical_feature = [col for col in df.columns if df[col].dtype != 'object']
categorical_feature = [col for col in df.columns if df[col].dtype == 'object']

# %%
print(numerical_feature)
# Out:
# ['Delivery_person_Age', 'Delivery_person_Ratings', 'distance', 'order_preparation_time', 'Vehicle_condition', 'multiple_deliveries', 'Time_taken (min)']

# %%
print(categorical_feature)
# Out:
# ['Weather_conditions', 'Road_traffic_density', 'Type_of_vehicle', 'Festival', 'City']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.hist(df['Time_taken (min)'],color='Orange')
plt.xlabel('Distribution of Time Taken in minutes')
plt.ylabel('Frequency')
plt.title("Histogram of Delivery time distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for col in numerical_feature:
    plt.hist(df[col], bins=30, edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
plt.figure(figsize=(10,5))
df['distance'].plot(kind = 'kde', title = 'distance')
plt.show()

# %%
# Bar plots for categorical features

for col in categorical_feature:
    plt.figure(figsize=(20,10))
    sns.countplot(x=df[col])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(15, 15))

axes[0,0].pie(df['Weather_conditions'].value_counts(),labels=df['Weather_conditions'].value_counts().index,autopct="%1.2f%%",rotatelabels=True)
axes[0,0].set_title("weather distribution")


axes[0,1].pie(df['Road_traffic_density'].value_counts(),labels=df['Road_traffic_density'].value_counts().index,autopct="%1.2f%%",rotatelabels=True)
axes[0,1].set_title("Road_traffic_density distribution")


axes[1, 0].pie(df['Type_of_vehicle'].value_counts(),labels=df['Type_of_vehicle'].value_counts().index,autopct="%1.2f%%",rotatelabels=True)
axes[1, 0].set_title("Type_of_vehicle distribution")


axes[1, 1].pie(df['Festival'].value_counts(),labels=df['Festival'].value_counts().index,autopct="%1.2f%%",rotatelabels=True)
axes[1, 1].set_title("Festival distribution")


axes[2, 0].pie(df['City'].value_counts(),labels=df['City'].value_counts().index,autopct="%1.2f%%",rotatelabels=True)
axes[2, 0].set_title("City distribution")



fig.show()

# %%
sns.barplot(x = 'Weather_conditions' , y = 'Time_taken (min)' , data = df)
plt.show()

# %%
for col in categorical_feature:
  sns.barplot(x = col , y = 'Time_taken (min)' , data = df)
  plt.show()

# %%
sns.pairplot(df[numerical_feature])

# %%
sns.heatmap(df[numerical_feature].corr(),annot = True)
# Out:
# <Axes: >

# %%
df.to_csv('cleaned_data.csv',index = False)
